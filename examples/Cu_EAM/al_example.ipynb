# %%
import pytint.kernel as pk

# %%
pk.spawn_jobs("input.yaml", rs=True)
# Out:
# Total number of 2 calculations registered

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
st, sfe, sferr = np.loadtxt("rs-FCC-1300-0.00-0.00/reversible_scaling.dat", unpack=True)
lt, lfe, lferr = np.loadtxt("rs-LQD-1300-0.00-0.00/reversible_scaling.dat", unpack=True)

# %%
plt.plot(st, sfe)
plt.plot(lt, lfe)
